# %% [markdown]
# # RiichiEnv Replay Viewer Demo
#
# This notebook demonstrates how to use the standalone Replay Viewer using a sample log provided in the repo.
# The viewer works completely client-side in the browser, meaning you can save this notebook as HTML or view it on NBViewer and the replay will still be interactive.

# %%
from riichienv import RiichiEnv
from riichienv.agents import RandomAgent


agent = RandomAgent()
env = RiichiEnv()
obs_dict = env.reset()
while not env.done():
    actions = {player_id: agent.act(obs)
               for player_id, obs in obs_dict.items()}
    obs_dict = env.step(actions)

scores, points, ranks = env.scores(), env.points(), env.ranks()
print(scores, points, ranks)
# Out:
# [25000, 25000, 25000, 25000] [50, 10, -10, -50] [1, 2, 3, 4]

# %%
from riichienv.visualizer import Replay

Replay.from_list(env.mjai_log)
# Out:
#         <div id="riichienv-viewer-0e9677d9-d191-4a50-b278-273b1f2dbb65" style="width: 100%; min-height: 600px; border: 1px solid #ddd;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "1f4d7d2f2b8594814821c63361dc061c";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"id": 0, "type": "start_game", "meta": {}}, {"bakaze": "E", "dora_marker": "S", "honba": 0, "kyoku": 1, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["1m", "5m", "6m", "9m", "1p", "2p", "6p", "6p", "6p", "4s", "6s", "8s", "P"], ["4m", "6m", "8m", "1p", "4p", "5pr", "8p", "8p", "9p", "9p", "2s", "3s", "S"], ["2m", "2m", "5m", "9m", "3p", "4p", "4s", "5s", "7s", "8s", "8s", "E", "C"], ["6m", "8m", "2p", "6p", "7p", "8p", "2s", "3s", "5s", "9s", "S", "N", "N"]], "type": "start_kyoku", "meta": {}}, {"actor": 0, "pai": "5p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "6s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "3p", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "5pr", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "consumed": ["3p", "4p"], "pai": "5pr", "target": 1, "type": "chi", "meta": {}}, {"actor": 2, "pai": "8s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "3p", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "8m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "8p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "6p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "7m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "9p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "1m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "E", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "1s", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "1s", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "4m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "4s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "4p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "4m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "5s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "1m", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "1m", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "8s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "5sr", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "4s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "consumed": ["3s", "5s"], "pai": "4s", "target": 2, "type": "chi", "meta": {}}, {"actor": 3, "pai": "N", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "9p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "N", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "2s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "W", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "1m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "9s", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "9s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "P", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "9p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "E", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "9p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "7p", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "2m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "5p", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "2p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "8m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "5m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "7s", "type": "tsumo", "meta": {}}, {"actor": ...

# %%
# log_path = '../tools/replay-visualizer/example_log_b124_m244_0.jsonl'
# Replay.from_jsonl(log_path)
