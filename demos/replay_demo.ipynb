# %% [markdown]
# # RiichiEnv Replay Viewer Demo
#
# This notebook demonstrates how to use the standalone Replay Viewer using a sample log provided in the repo.
# The viewer works completely client-side in the browser, meaning you can save this notebook as HTML or view it on NBViewer and the replay will still be interactive.

# %%
from riichienv import RiichiEnv
from riichienv.visualizer import Replay
from riichienv.agents import RandomAgent


agent = RandomAgent()
env = RiichiEnv(game_mode="4p-red-half")
obs_dict = env.reset()
while not env.done():
    actions = {player_id: agent.act(obs)
               for player_id, obs in obs_dict.items()}
    obs_dict = env.step(actions)

scores, points, ranks = env.scores(), env.points(), env.ranks()
print(scores, points, ranks)
# Out:
# [23000, 27000, 23000, 27000] [-12, 52, -52, 12] [3, 1, 4, 2]

# %%
Replay.from_list(env.mjai_log)
# Out:
#         <div id="riichienv-viewer-c599593d-0572-4db9-8a02-bea4dffde279" style="width: 100%; min-height: 600px; border: 1px solid #ddd;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "bef024606d7f55e0618be9110a082084";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"id": 0, "type": "start_game", "meta": {}}, {"bakaze": "E", "dora_marker": "5s", "honba": 0, "kyoku": 1, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["6m", "5p", "7p", "1s", "3s", "8s", "8s", "E", "E", "S", "W", "N", "N"], ["2p", "3p", "3p", "4p", "5pr", "7p", "1s", "1s", "3s", "5s", "7s", "S", "N"], ["1m", "2m", "4m", "4m", "8m", "3p", "5p", "9p", "9p", "9p", "4s", "7s", "F"], ["1m", "6m", "2p", "4p", "4p", "8p", "9p", "3s", "7s", "9s", "9s", "W", "F"]], "type": "start_kyoku", "meta": {}}, {"actor": 0, "pai": "9s", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "S", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "3p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "5m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "4s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "C", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "3s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "8p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "7p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "5mr", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "5mr", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "8s", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "5p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "6s", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "4m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "6m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "9s", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "2m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "8m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "5s", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "9s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "C", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "3s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "5s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "1m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "4m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "P", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "F", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "3p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "C", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "N", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "3p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "7s", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "4m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "4p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "2s", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "8s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "consumed": ["7s", "9s"], "pai": "8s", "target": 0, "type": "chi", "meta": {}}, {"actor": 1, "pai": "N", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "consumed": ["N", "N"], "pai": "N", "target": 1, "type": "pon", "meta": {}}, {"actor": 0, "pai": "E", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "6p", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "3s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2s", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "3p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "8p", "type": "tsumo", "meta": {}}, {"actor": 3, "pai" ...

# %%
# log_path = '../tools/replay-visualizer/example_log_b124_m244_0.jsonl'
# Replay.from_jsonl(log_path)
