# %% [markdown]
# # RiichiEnv Replay Viewer Demo
#
# This notebook demonstrates how to use the standalone Replay Viewer using a sample log provided in the repo.
# The viewer works completely client-side in the browser, meaning you can save this notebook as HTML or view it on NBViewer and the replay will still be interactive.

# %%
from riichienv import RiichiEnv
from riichienv.visualizer import Replay
from riichienv.agents import RandomAgent


agent = RandomAgent()
env = RiichiEnv(game_mode="4p-red-half")
obs_dict = env.reset()
while not env.done():
    actions = {player_id: agent.act(obs)
               for player_id, obs in obs_dict.items()}
    obs_dict = env.step(actions)

scores, points, ranks = env.scores(), env.points(), env.ranks()
print(scores, points, ranks)
# Out:
# [25000, 25000, 25000, 25000] [50, 10, -10, -50] [1, 2, 3, 4]

# %%
Replay.from_list(env.mjai_log)
# Out:
#         <div id="riichienv-viewer-4fa36fb6-4921-4e38-a630-6c505d9d7820" style="width: 100%; min-height: 600px; border: 1px solid #ddd;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "4e07f231bcdbf191dfb74c9ee151f1d6";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"id": 0, "type": "start_game", "meta": {}}, {"bakaze": "E", "dora_marker": "4p", "honba": 0, "kyoku": 1, "kyotaku": 0, "oya": 0, "scores": [25000, 25000, 25000, 25000], "tehais": [["3m", "7m", "1p", "1p", "7p", "1s", "4s", "5sr", "6s", "6s", "P", "P", "F"], ["1m", "3m", "4m", "7m", "9m", "7p", "7p", "1s", "4s", "5s", "S", "N", "F"], ["6m", "6m", "7m", "1p", "2p", "3p", "6p", "7p", "1s", "1s", "2s", "4s", "W"], ["2m", "7m", "3p", "5pr", "6p", "8p", "9p", "9p", "5s", "7s", "8s", "E", "F"]], "type": "start_kyoku", "meta": {}}, {"actor": 0, "pai": "9s", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "P", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "4p", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "1m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "5p", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "2s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "C", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "3p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "8s", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "1p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "9m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "5s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "C", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "1p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "F", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "C", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "4p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "1p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "5mr", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "5mr", "tsumogiri": true, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "4s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "E", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "F", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "P", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "8p", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "N", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "9m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "1s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "6p", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "E", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "5m", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "2m", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "4m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "1s", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "2m", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "7p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "consumed": ["6p", "8p"], "pai": "7p", "target": 2, "type": "chi", "meta": {}}, {"actor": 3, "pai": "9p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "3p", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "7p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "P", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "F", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 2, "pai": "E", "type": "tsumo", "meta": {}}, {"actor": 2, "pai": "5p", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 3, "pai": "S", "type": "tsumo", "meta": {}}, {"actor": 3, "pai": "F", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 0, "pai": "4s", "type": "tsumo", "meta": {}}, {"actor": 0, "pai": "F", "tsumogiri": false, "type": "dahai", "meta": {}}, {"actor": 1, "pai": "6m", "type": "tsumo", "meta": {}}, {"actor": 1, "pai": "4s", "tsumogiri": false, "type":  ...

# %%
# log_path = '../tools/replay-visualizer/example_log_b124_m244_0.jsonl'
# Replay.from_jsonl(log_path)
