# %%
import json

from riichienv import parse_hand
from riichienv import convert as cvt
from riichienv.visualizer import Replay

events_str = """
{"type":"start_game","names":["0","1","2","3"],"seed":[88926,85618]}
{"type":"start_kyoku","bakaze":"E","dora_marker":"3m","kyoku":3,"honba":0,"kyotaku":0,"oya":2,"scores":[22900,44900,24200,8000],"tehais":[["9s","1s","C","9s","7p","6s","E","3m","3s","S","4p","N","N"],["2p","4m","7s","1m","6p","W","1p","7s","3p","9m","9m","3m","4p"],["4m","2p","3s","5sr","1p","7p","8p","1m","9m","N","8s","8m","8s"],["F","3m","9p","8p","2s","1m","9p","1p","7m","8s","9s","7m","2m"]]}
{"type":"tsumo","actor":2,"pai":"8m"}
{"type":"dahai","actor":2,"pai":"1m","tsumogiri":false}
{"type":"tsumo","actor":3,"pai":"4m"}
{"type":"dahai","actor":3,"pai":"1p","tsumogiri":false}
{"type":"tsumo","actor":0,"pai":"6m"}
{"type":"dahai","actor":0,"pai":"S","tsumogiri":false}
{"type":"tsumo","actor":1,"pai":"7p"}
{"type":"dahai","actor":1,"pai":"F","tsumogiri":false}
{"type":"ryukyoku","reason":"Error: Illegal Action","deltas":[4000,-12000,4000,4000]}
{"type":"end_kyoku"}
{"type":"end_game"}
"""
events = [json.loads(ev_str) for ev_str in events_str.strip().split("\n")]
Replay.from_list(events, step=141, freeze=True)
# Out:
#         <div id="riichienv-viewer-679bf692-a531-468b-8cd3-82039976db6b" style="width: 100%; min-height: 600px; border: 1px solid #ddd; box-sizing: border-box;">
#              <div style="padding: 20px; text-align: center; font-family: sans-serif; color: #666;">
#                 Loading RiichiEnv Replay...
#              </div>
#         </div>
#         <script>
#         (function() {
#             const expectedHash = "0fb7efa92264d8354d3a11b3da205231";
#
#             const runViewer = (jsCode) => {
#                 try {
#                     if (jsCode) {
#                         const script = document.createElement('script');
#                         script.text = jsCode;
#                         document.head.appendChild(script);
#                         // Store the hash after loading new code
#                         window.RiichiEnvViewerHash = expectedHash;
#                     }
#
#                     const logData = [{"type": "start_game", "names": ["0", "1", "2", "3"], "seed": [88926, 85618], "meta": {}}, {"type": "start_kyoku", "bakaze": "E", "dora_marker": "3m", "kyoku": 3, "honba": 0, "kyotaku": 0, "oya": 2, "scores": [22900, 44900, 24200, 8000], "tehais": [["9s", "1s", "C", "9s", "7p", "6s", "E", "3m", "3s", "S", "4p", "N", "N"], ["2p", "4m", "7s", "1m", "6p", "W", "1p", "7s", "3p", "9m", "9m", "3m", "4p"], ["4m", "2p", "3s", "5sr", "1p", "7p", "8p", "1m", "9m", "N", "8s", "8m", "8s"], ["F", "3m", "9p", "8p", "2s", "1m", "9p", "1p", "7m", "8s", "9s", "7m", "2m"]], "meta": {}}, {"type": "tsumo", "actor": 2, "pai": "8m", "meta": {}}, {"type": "dahai", "actor": 2, "pai": "1m", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 3, "pai": "4m", "meta": {}}, {"type": "dahai", "actor": 3, "pai": "1p", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 0, "pai": "6m", "meta": {}}, {"type": "dahai", "actor": 0, "pai": "S", "tsumogiri": false, "meta": {}}, {"type": "tsumo", "actor": 1, "pai": "7p", "meta": {}}, {"type": "dahai", "actor": 1, "pai": "F", "tsumogiri": false, "meta": {}}, {"type": "ryukyoku", "reason": "Error: Illegal Action", "deltas": [4000, -12000, 4000, 4000], "meta": {}}, {"type": "end_kyoku", "meta": {}}, {"type": "end_game", "meta": {}}];
#                     const initialStep = 141;
#                     const perspective = undefined;
#                     const freeze = true;
#                     if (window.RiichiEnvViewer) {
#                         new window.RiichiEnvViewer("riichienv-viewer-679bf692-a531-468b-8cd3-82039976db6b", logData, initialStep, perspective, freeze);
#                     } else {
#                         throw new Error("RiichiEnvViewer global not found after injection");
#                     }
#                 } catch (e) {
#                     console.error("RiichiEnv Viewer Error:", e);
#                     document.getElementById("riichienv-viewer-679bf692-a531-468b-8cd3-82039976db6b").innerHTML = "Error: " + e.message;
#                 }
#             };
#
#             // Check if global exists AND matches expected hash
#             if (window.RiichiEnvViewer && window.RiichiEnvViewerHash === expectedHash) {
#                 runViewer("");
#             } else {
#                 // Decompress and load New Code
#                 const b64Data = "...";
#                 const compressed = Uint8Array.from(atob(b64Data), c => c.charCodeAt(0));
#
#                 if (window.DecompressionStream) {
#                     const ds = new DecompressionStream('gzip');
#                     const decompressedStream = new Response(compressed).body.pipeThrough(ds);
#                     new Response(decompressedStream).text().then(runViewer).catch(e => {
#                         document.getElementById("riichienv-viewer-679bf692-a531-468b-8cd3-82039976db6b").innerHTML = "Error decompressing: " + e.message;
#                     });
#                 } else {
#                     const err = "Error: Browser too old (DecompressionStream missing).";
#                     document.getElementById("riichienv-viewer-679bf692-a531-468b-8cd3-82039976db6b").innerHTML = err;
#                 }
#             }
#         })();
#         </script>
